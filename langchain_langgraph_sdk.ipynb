# %% [markdown]
# <a href="https://colab.research.google.com/github/gayashan4lk/langchain-for-app-development/blob/main/langchain_langgraph_sdk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain-core langchain-text-splitters langchain-mcp-adapters langchain-tests

# %% [markdown]
# # langchain
#
# The main entrypoint containing all implementations you need for building applications with LLMs.
#
# *   agents
# *   chat models
# *   embeddings
# *   rate limiters
# *   tools

# %%
import langchain.agents
import langchain.chat_models
import langchain.embeddings
import langchain.rate_limiters
import langchain.tools

# %% [markdown]
# # langchain-core
#
# Core interfaces and abstractions used across the LangChain ecosystem.
#
# - Caches: Caching mechanisms.
# -  Callbacks: Callback handlers and management.
# -  Documents: Document abstractions.
# - Embeddings: Embedding abstractions.
# - Exceptions: Common LangChain exception types.
# - Language models: Base interfaces for language models.
# - Serialization: Components for serialization and deserialization.
# - Output parsers: Parsing model outputs.
# - Prompts: Prompt templates and related utilities.
# - Rate limiters: Rate limiting utilities.
# - Retrievers: Retriever interfaces and implementations.
# - Runnables: Runnables and related abstractions.
# - Utilities: Various utility functions and classes.
# - Vector stores: Vector store interfaces and implementations.

# %%
import langchain_core.caches
import langchain_core.callbacks
import langchain_core.documents
import langchain_core.exceptions
import langchain_core.language_models
import langchain_core.output_parsers
import langchain_core.prompts
import langchain_core.rate_limiters
import langchain_core.retrievers
import langchain_core.runnables
import langchain_core.utils
import langchain_core.vectorstores

# %% [markdown]
# # langchain-text-splitters
#
# Text splitting utilities for document processing.

# %%
import langchain_text_splitters

# %% [markdown]
# # langchain-mcp-adapters
#
# Make MCP tools available in LangChain and LangGraph applications.

# %%
import langchain_mcp_adapters

# %% [markdown]
# # langchain-tests
#
# Standard tests suite used to validate LangChain integration package implementations.

# %%
import langchain_tests.base
import langchain_tests.conftest
import langchain_tests.utils
import langchain_tests.unit_tests
import langchain_tests.integration_tests

# %% [markdown]
# # langgraph
# Core interfaces you will use when building with LangGraph. Each section covers a different part of the ecosystem.

# %%
# !pip install -U langgraph

# %% [markdown]
# The core APIs for the LangGraph open source library.
#
# - Graphs: Main graph abstraction and usage.
# - Functional API: Functional programming interface for graphs.
# - Pregel: Pregel-inspired computation model.
# - Checkpointing: Saving and restoring graph state.
# - Storage: Storage backends and options.
# - Caching: Caching mechanisms for performance.
# - Types: Type definitions for graph components.
# - Runtime: Runtime configuration and options.
# - Config: Configuration options.
# - Errors: Error types and handling.
# - Constants: Global constants.
# - Channels: Message passing and channels.

# %%
import langgraph.graph
import langgraph.func
import langgraph.pregel
import langgraph.checkpoint
import langgraph.store
import langgraph.cache
import langgraph.types
import langgraph.runtime
import langgraph.config
import langgraph.errors
import langgraph.constants
import langgraph.channels
